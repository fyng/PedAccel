# %% [markdown]
# Accelerometry MAD Plots for All Patients

# %%
# Import Modules
import os
from scipy.io import loadmat
import Plot

# %%
data_dir = r'C:\Users\sidha\OneDrive\Sid Stuff\PROJECTS\iMEDS Design Team\Data Analysis\PedAccel\data_analysis\PythonPipeline\PatientData'

for patient in os.listdir(data_dir):
    patient_dir = os.path.join(data_dir, patient)
    if os.path.isdir(patient_dir):
        print('Processing:', patient)

        print('Loading data')
            
        filename = f'{patient}_10MIN_5MIN.mat'
            
        data_path = os.path.join(patient_dir, filename)
        data = loadmat(data_path)
        
        x_mag = data["x_mag"]
        sbs = data["sbs"].flatten()
        
        Plot.mad_plot(sbs, x_mag, 100, None)
# Out:
# Processing: Patient11
# Loading data
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# Processing: Patient12
# Loading data
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# 900
# Processing: Patient13
# Loading data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\sidha\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# ...
