# %% [markdown]
# CCDA SBS Extraction Code

# %%
# Import Modules
import pandas as pd
import numpy as np
from openpyxl import load_workbook
import os
os.chdir(r'S:\Sedation_monitoring')

# %%
# Open Workbook

# Specify the path to the Excel file
file_path = 'CCDA_6771_Extract_03042024.xlsx'

# Load the Excel workbook
workbook = load_workbook(file_path)

# worksheet = workbook['Sheet1']  # Replace 'Sheet1' with the actual sheet name
worksheet = workbook['ABCDEF Bundle']

# Now you can access data from the worksheet
# For example, to get the value of cell A1:
# cell_value = worksheet['A1'].value

# %%
# Access SBS Scores for given MRN

# Input Patient MRN
patient_mrn = 'JH07596734'

# Make Blank 2D Array
sbs_scores = []

for cell_c, cell_i, cell_k in zip(worksheet['C'][1:], worksheet['I'][1:], worksheet['K'][1:]):
    # Access the value of the cells in columns C and I
    value_c = cell_c.value
    value_i = cell_i.value
    value_k = cell_k.value
    
    # Check if the value in column C matches the desired value
    if value_c == patient_mrn:
        # Access the corresponding value in column I at the same row
        # Do something with the value in column I
        if value_i[0] == '0' or value_i[1] in ['1', '2', '3']:
            sbs_scores.append([value_k, value_i])
            print(sbs_scores)

# Once you're done working with the workbook, you can close it
workbook.close()
# Out:
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm']]
# ...
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 16, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 4, 0), '0 Awake and Able to calm']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 16, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 4, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 29, 20, 0), '0 Awake and Able to calm']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 16, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 4, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 29, 20, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 0, 0), '0 Awake and Able to calm']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 16, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 4, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 29, 20, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 8, 0), '0 Awake and Able to calm']]
# [[datetime.datetime(2023, 11, 24, 8, 26), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 13, 40), '+2 Agitated'], [datetime.datetime(2023, 11, 25, 5, 10), '+2 Agitated'], [datetime.datetime(2023, 11, 24, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 7, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 25, 23, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 3, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 5, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 26, 22, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 1, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 2, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 6, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 27, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 0, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 12, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 28, 20, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 4, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 8, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 29, 16, 0), '-1 Responsive to gentle touch or voice'], [datetime.datetime(2023, 11, 24, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 12, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 24, 16, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 25, 4, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 29, 20, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 0, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 8, 0), '0 Awake and Able to calm'], [datetime.datetime(2023, 11, 30, 20, 0), '0 Awake and Able to calm']]

# %%
# Once you're done working with the workbook, you can close it
workbook.close()
