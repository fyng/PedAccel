# %%
#import relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pyarrow as pa
import seaborn as sns
from datetime import timedelta, datetime

dir = Path(r"S:\Fackler_OSS_364376\data\IRB-364376-v1-230215")

# %%
# read ptsd records
fp = dir.joinpath('EHR', 'ptsd_record.csv.gz')
ptsd_record = pd.read_csv(fp, compression="gzip")
patients_ptsd = ptsd_record['pat_enc_csn_sid'].unique()

# read flow table of patient EHR records
fp = dir.joinpath('EHR', 'flowsheet.csv.gz')
data = pd.read_csv(fp, compression="gzip")
data = data.drop(columns = ['meas_comment', 'meas_template_id'])
# Note: pandas took 50 seconds to load the table. Consider porting to PySpark RDD

# %%
fp = dir.joinpath('EHR', 'd_flo_measures.csv.gz')
dict = pd.read_csv(fp, compression="gzip")

names = ["State Behavioral Scale",
"-3 Unresponsive", 
"-2 Responsive to noxious stimuli", 
"-1 Responsive to gentle touch or voice",
"0 Awake and Able to calm",
"+1 Restless and difficult to calm",
"+2 Agitated",
"State Behavioral Scale (SBS)",
"Achieved Level of Sedation",
"Sedation / Delirium",
"Richmond Agitation - Sedation Scale",
"Richmond agitation sedation scale",
"Richmond Agitation Sedation Scale (RASS)"]

# dict[dict['disp_name'].isin(names)]

# %%
# flow_meas_id for SBS and RASS
fmid = [304080016, 304080017, 304080018, 304080019, 304080020, 304080021]

sbs = data[data['meas_id'].isin(fmid)]
print(sbs.shape)
# 25878 entries

# calculate sbs score from offset
sbs['SBS'] = sbs['meas_id'] - 304080019
sbs = sbs.drop(columns=['meas_value', 'meas_id'])
sbs['recorded_time'] = pd.to_datetime(sbs['recorded_time'], format='%Y-%m-%d %H:%M:%S')
sbs_indiv = sbs.groupby('pat_enc_csn_sid')

# Identify patients with SBS and waveform data
patients_ehr = list(sbs_indiv.groups.keys())

patients = set(patients_ehr) & set(patients_ptsd)

print(len(patients_ehr))
print(len(patients_ptsd))
print(len(patients))
# Out:
# (25878, 5)
# 1351
# 748
# 581
# c:\Program Files\miniconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# # Inclusion Exclusion criteria
# - patients on ventilator
#         - contains MEDIBUSVITALS file (from Drager ventilator)
#         - overlapping ventilator time in (vent_dur)
#         -
# - patient on beta blocker
# - patients on neuromuscular blockers

# %% [markdown]
# ### Mechanical ventilators

# %% [markdown]
# levels of ventilator support
# - 1: room air
# - 2: supplemental O2
# - 3: regular nasal cannula
# - 4: high-flow nasal cannula
# - 5: noninvasive positive pressure ventilation
# - 6: conventional mechanical ventilation
# - 7: high freq oscillation or jet ventilation

# %%
fp = dir.joinpath('EHR', 'vent_dur.csv.gz')
vent_record = pd.read_csv(fp, compression="gzip")

mech_vent = [5, 6, 7]
vent_record = vent_record[vent_record['level'].isin(mech_vent)]
vent_record.head()
# Out:
#                                osler_sid  pat_enc_csn_sid  seq  level  \
# 3   8D48836C-6F5F-4270-8DB6-A058C3607B24       1000005531   24      6
# 5   4EA242D1-FE29-4F21-B284-3AB7D08A31AF       1000000332    2      6
# 11  047A349F-0410-4AA8-88A8-A781FAE1570E       1000000003    5      6
# 12  047A349F-0410-4AA8-88A8-A781FAE1570E       1000000003    6      6
# 17  047A349F-0410-4AA8-88A8-A781FAE1570E       1000000579    2      6
#
#              start_time            stop_time   last_recorded_time     dur_hr  \
# 3   2018-10-31 07:50:00  2018-10-31 17:50:00  2018-10-31 17:49:00  10.000000
# 5   2017-06-06 10:39:00  2017-06-06 11:50:00  2017-06-06 10:51:00   1.183333
# 11  2016-07-08 21:38:00  2016-07-11 14:25:00  2016-07-11 08:15:00  64.783333
# 12  2016-07-11 14:25:00  2016-07-13 14:56:00  2016-07-13 08:02:00  48.516666
# 17  2016-07-07 10:22:00  2016-07-07 14:45:00  2016-07-07 12:57:00   4.383333
#
#      post_hr
# 3   0.016666
# 5   0.983333
# 11  6.166666
# 12  6.900000
# 17  1.800000

# %%
patient_vent = set(vent_record['pat_enc_csn_sid'])
patients = patients - patient_vent
len(patients)
# 324 patients never on mechanical ventilators throughout stay
# Out:
# 324

# %% [markdown]
# ### Drug
# exclude neuromuscular and beta blockers

# %% [markdown]
# - medication dictionary: d_med
# - accm_med_admin
# - anes_dur

# %%
fp = dir.joinpath('EHR', 'med_admin.csv.gz')
med_admin = pd.read_csv(fp, compression="gzip")

med_admin.head()
# Out:
# c:\Program Files\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (26,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                               osler_sid  pat_enc_csn_sid  order_med_sid  line  \
# 0  567070AE-DFC6-438F-90C7-D5045EE7C0C3       1000000152        3006487    10
# 1  567070AE-DFC6-438F-90C7-D5045EE7C0C3       1000000152        3006487    11
# 2  567070AE-DFC6-438F-90C7-D5045EE7C0C3       1000000152        3006487    12
# 3  567070AE-DFC6-438F-90C7-D5045EE7C0C3       1000000152        3006487    13
# 4  567070AE-DFC6-438F-90C7-D5045EE7C0C3       1000000152        3006487    14
#
#        hosp_admsn_time      hosp_disch_time  \
# 0  2016-12-06 16:28:00  2016-12-16 12:08:00
# 1  2016-12-06 16:28:00  2016-12-16 12:08:00
# 2  2016-12-06 16:28:00  2016-12-16 12:08:00
# 3  2016-12-06 16:28:00  2016-12-16 12:08:00
# 4  2016-12-06 16:28:00  2016-12-16 12:08:00
#
#                                      medication_name  \
# 0  HEPARIN (PORCINE) (PF) 1,000 UNIT/500 ML IN 0....
# 1  HEPARIN (PORCINE) (PF) 1,000 UNIT/500 ML IN 0....
# 2  HEPARIN (PORCINE) (PF) 1,000 UNIT/500 ML IN 0....
# 3  HEPARIN (PORCINE) (PF) 1,000 UNIT/500 ML IN 0....
# 4  HEPARIN (PORCINE) (PF) 1,000 UNIT/500 ML IN 0....
#
#                                         generic_name  medication_id  \
# 0  heparin (porcine) (PF) 1,000 unit/500 mL in 0....      4089008.0
# 1  heparin (porcine) (PF) 1,000 unit/500 mL in 0....      4089008.0
# 2  heparin (porcine) (PF) 1,000 unit/500 mL in 0....      4089008.0
# 3  heparin (porcine) (PF) 1,000 unit/500 mL in 0....      4089008.0
# 4  heparin (porcine) (PF) 1,000 unit/500 mL in 0....      4089008.0
#
#   thera_classname  ... number_of_times time_unit now_yn reason  \
# 0  ANTICOAGULANTS  ...             NaN       NaN    NaN    NaN
# 1  ANTICOAGULANTS  ...             NaN       NaN    NaN    NaN
# 2  ANTICOAGULANTS  ...             NaN       NaN    NaN    NaN
# 3  ANTICOAGULANTS  ...             NaN       NaN    NaN    NaN
# 4  ANTICOAGULANTS  ...             NaN       NaN    NaN    NaN
#
#   mar_imm_link_id    mar_admin_dept mar_ord_dat pat_supplied_yn sensitive_yn  \
# 0             NaN  JHH BLOOMBERG 4S         NaN             NaN            N
# 1             NaN  JHH BLOOMBERG 4S         NaN             NaN            N
# 2             NaN  JHH BLOOMBERG 4S         NaN             NaN            N
# 3             NaN  JHH BLOOMBERG 4S         NaN             NaN            N
# 4             NaN  JHH BLOOMBERG 4S         NaN             NaN            N
#
#    mar_action_c
# 0           121
# 1           121
# 2           121
# 3           121
# 4           121
#
# [5 rows x 43 columns]

# %%
print(med_admin.keys())
print(med_admin['pharm_classname'].unique())
# Out:
# Index(['osler_sid', 'pat_enc_csn_sid', 'order_med_sid', 'line',
#        'hosp_admsn_time', 'hosp_disch_time', 'medication_name', 'generic_name',
#        'medication_id', 'thera_classname', 'pharm_classname',
#        'pharm_subclassname', 'taken_time', 'ordering_date', 'order_end_time',
#        'scheduled_time', 'saved_time', 'mar_time_source', 'mar_action',
#        'user_sid', 'mar_doc_user_sid', 'mar_billing_prov_sid', 'route', 'sig',
#        'site', 'dose_unit', 'infusion_rate', 'mar_inf_rate_unit',
#        'mar_duration', 'duration_unit', 'frequency', 'freq_period',
#        'freq_type', 'number_of_times', 'time_unit', 'now_yn', 'reason',
#        'mar_imm_link_id', 'mar_admin_dept', 'mar_ord_dat', 'pat_supplied_yn',
#        'sensitive_yn', 'mar_action_c'],
#       dtype='object')
# ['HEPARIN AND RELATED PREPARATIONS' 'OPIOID ANALGESICS' nan
#  'COMPOUNDING KIT' 'ANTIHISTAMINES - 1ST GENERATION'
#  'ANTICHOLINERGICS,QUATERNARY AMMONIUM' 'ANTISERA'
#  'CEPHALOSPORIN ANTIBIOTICS - 1ST GENERATION' 'OSMOTIC DIURETICS'
#  'LOOP DIURETICS' 'ELECTROLYTE MAINTENANCE'
#  'OPIOID ANALGESIC, ANESTHETIC ADJUNCT AGENTS' 'CALCIUM REPLACEMENT'
#  'ANALGESIC/ANTIPYRETICS,NON-SALICYLATE' 'GLUCOCORTICOIDS'
#  'SODIUM/SALINE PREPARATIONS' 'ANTI-ANXIETY - BENZODIAZEPINES'
#  'TOPICAL ANTIBIOTICS' 'ABSORBABLE SULFONAMIDE ANTIBACTERIAL AGENTS'
#  'THROMBOLYTIC ENZYMES'
#  'URINARY TRACT ANTISPASMODIC/ANTIINCONTINENCE AGENT'
#  'GENERAL INHALATION AGENTS' 'SOMATOSTATIC AGENTS'
#  'NEUROMUSCULAR BLOCKING AGENTS' 'OSTOMY SUPPLIES' 'ANTIFUNGAL AGENTS'
#  'IV FAT EMULSIONS' 'PENICILLIN ANTIBIOTICS'
#  'ANAEROBIC ANTIPROTOZOAL-ANTIBACTERIAL AGENTS'
#  'CEPHALOSPORIN ANTIBIOTICS - 3RD GENERATION' 'POTASSIUM REPLACEMENT'
#  'IV SOLUTIONS: DEXTROSE-SALINE' 'SEDATIVE-HYPNOTICS,NON-BARBITURATE'
#  'PULM.ANTI-HTN,SEL.C-GMP PHOSPHODIESTERASE T5 INHIB'
#  'PEDIATRIC VITAMIN PREPARATIONS' 'MUCOLYTICS'
#  'GENERAL ANESTHETICS,INJECTABLE-BENZODIAZEPINE TYPE'
#  'GENERAL ANESTHETICS,INJECTABLE' 'ANTICONVULSANTS'
#  'SELECTIVE RELAXANT BINDING AGENTS (SRBAS)' 'VITAMIN C PREPARATIONS'
#  'CEPHALOSPORIN ANTIBIOTICS - 4TH GENERATION'
#  'EYE PREPARATIONS, MISCELLANEOUS (OTC)' 'TOPICAL LOCAL ANESTHETICS'
#  'ANTACIDS' 'ANTIEMETIC/ANTIVERTIGO AGENTS'
#  'ANTINEOPLASTIC - ALKYLATING AGENTS'
#  'ANTINEOPLASTIC EGF RECEPTOR BLOCKER MCLON ANTIBODY'
#  'MACROLIDE ANTIBIOTICS' 'SEDATIVE-HYPNOTICS - BENZODIAZEPINES'
#  'VANCOMYCIN ANTIBIOTICS AND DERIVATIVES'
#  'BETA-ADRENERGIC AGENTS, INHALED, SHORT ACTING' 'TOPICAL ANTIFUNGALS'
#  'ARTIFICIAL TEARS' 'LAXATIVES AND CATHARTICS'
#  'GLUCOCORTICOIDS, ORALLY INHALED' 'PROTON-PUMP INHIBITORS'
#  'OPHTHALMIC ANTIBIOTICS' 'FLUORIDE PREPARATIONS' 'KERATOLYTICS'
#  'ANTIHISTAMINES - 2ND GENERATION' 'BELLADONNA ALKALOIDS'
#  'LINCOSAMIDE ANTIBIOTICS' 'ANTICHOLINERGICS, ORALLY INHALED SHORT ACTING'
#  'HISTAMINE H2-RECEPTOR INHIBITORS' 'VASODILATORS,PERIPHERAL'
#  'EYE ANTI-INFLAMMATORY AGENTS' 'CALCIUM CHANNEL BLOCKING AGENTS'
#  'LAXATIVES, LOCAL/RECTAL' 'LOCAL ANESTHETICS'
#  'BETA-ADRENERGIC BLOCKING AGENTS' 'ANTIHYPERTENSIVES, VASODILATORS'
#  'ANTIHYPERTENSIVES, SYMPATHOLYTIC'
#  'NSAIDS, CYCLOOXYGENASE INHIBITOR TYPE ANALGESICS'
#  'IV SOLUTIONS: DEXTROSE-WATER' 'BARBITURATES'
#  'ANTIPROTOZOAL DRUGS,MISCELLANEOUS' 'THIAZIDE AND RELATED DIURETICS'
#  'PHOSPHATE REPLACEMENT' 'IV SOLUTIONS: DEXTROSE AND LACTATED RINGERS'
#  'NOSE PREPARATIONS, VASOCONSTRICTORS(OTC)'
#  'ANTIDIARRHEAL MICROORGANISMS AGENTS' 'ANTIFUNGAL ANTIBIOTICS'
#  'ANTIVIRALS, GENERAL' 'URINARY PH MODIFIERS' 'IMMUNOSUPPRESSIVES'
#  'CHOLINESTERASE INHIBITORS' 'GENERAL BRONCHODILATOR AGENTS'
#  'EYE ANTIBIOTIC AND GLUCOCORTICOID COMBINATIONS' 'TOPICAL ANTIPARASITICS'
#  'PROTECTIVES' 'TOPICAL ANTI-INFLAMMATORY STEROIDAL'
#  'NASAL ANTI-INFLAMMATORY STEROIDS' 'LEUKOTRIENE RECEPTOR ANTAGONISTS'
#  'EYE SULFONAMIDES' 'ADRENERGIC AGENTS,CATECHOLAMINES'
#  'LEUKOCYTE (WBC) STIMULANTS' 'CARBAPENEM ANTIBIOTICS (THIENAMYCINS)'
#  'CARDIOVASCULAR DIAGNOSTICS-RADIOPAQUE' 'EMOLLIENTS'
#  'VITAMIN D PREPARATIONS' 'DIAGNOSTIC PREPARATIONS,MISCELLANEOUS'
#  'EYE VASOCONSTRICTORS' 'ANTIEMETIC, CANNABINOID-TYPE'
#  'PINEAL HORMONE AGENTS' 'VITAMIN B1 PREPARATIONS' 'ELECTROLYTE DEPLETERS'
#  'SKELETAL MUSCLE RELAXANTS' 'QUINOLONE ANTIBIOTICS' 'TOPICAL HEMOSTATICS'
#  'MYDRIATICS' 'SYMPATHOMIMETIC AGENTS' 'PLASMA PROTEINS'
#  'ANTIFIBRINOLYTIC AGENTS' 'ANTIARRHYTHMICS' 'AMINOGLYCOSIDE ANTIBIOTICS'
#  'CEPHALOSPORIN ANTIBIOTICS - 2ND GENERATION' 'EYE IRRIGATIONS'
#  'INFLUENZA VIRUS VACCINES' 'ADRENOCORTICOTROPHIC HORMONES'
#  'TOPICAL SULFONAMIDES' 'ANTICONVULSANT - BENZODIAZEPINE TYPE'
#  'METABOLIC DEFICIENCY AGENTS' 'PLATELET AGGREGATION INHIBITORS'
#  'COAGULANTS' 'GENERAL ANESTHETICS,INHALANT' 'ANAPHYLAXIS THERAPY AGENTS'
#  'BICARBONATE PRODUCING/CONTAINING AGENTS' 'POTASSIUM SPARING DIURETICS'
#  'ANTIDIURETIC AND VASOPRESSOR HORMONES' 'THYROID HORMONES'
#  'ANTIPSYCHOTIC,ATYPICAL,DOPAMINE,SEROTONIN ANTAGNST'
#  'ANTIBIOTIC ANTINEOPLASTICS' 'ANALGESIC/ANTIPYRETICS, SALICYLATES'
#  'ALPHA/BETA-ADRENERGIC BLOCKING AGENTS' 'METABOLIC FUNCTION DIAGNOSTICS'
#  'TOPICAL/MUCOUS MEMBR./SUBCUT. ENZYMES' 'CARBONIC ANHYDRASE INHIBITORS'
#  'ANTI-INFLAM. INTERLEUKIN-1 RECEPTOR ANTAGONIST'
#  'CHEMOTHERAPY RESCUE/ANTIDOTE AGENTS' 'ANTIDOTES,MISCELLANEOUS'
#  'INSULINS' 'INTESTINAL MOTILITY STIMULANTS' 'CARDIOPLEGIC SOLUTIONS'
#  'ANTIFIBROTIC THERAPY - PYRIDONE ANALOGS' 'BENZODIAZEPINE ANTAGONISTS'
#  'GRAM POSITIVE COCCI VACCINES' 'VITAMIN B6 PREPARATIONS'
#  'BETA-ADRENERGIC AGENTS'
#  'BETA-ADRENERGIC AND ANTICHOLINERGIC COMBO, INHALED' 'IRON REPLACEMENT'
#  'ANTIPARKINSONISM DRUGS,OTHER' 'ACNE AGENTS,SYSTEMIC'
#  'DENTAL AIDS AND PREPARATIONS' 'VITAMIN K PREPARATIONS'
#  'GASTROINTESTINAL RADIOPAQUE DIAGNOSTICS' 'VASODILATORS,CORONARY'
#  'TX FOR ADHD - SELECTIVE ALPHA-2 RECEPTOR AGONIST'
#  'TX FOR ATTENTION DEFICIT-HYPERACT(ADHD)/NARCOLEPSY'
#  'NITROFURAN DERIVATIVES ANTIBACTERIAL AGENTS'
#  'ANTIPARKINSONISM DRUGS,ANTICHOLINERGIC' 'ANTIFLATULENTS'
#  'URINARY TRACT RADIOPAQUE DIAGNOSTICS'
#  'MU-OPIOID RECEPTOR ANTAGONISTS,PERIPHERALLY-ACTING'
#  'ANTI-ULCER PREPARATIONS' 'ANTISEPTICS,MISCELLANEOUS' 'IRRIGANTS'
#  'VITAMIN B PREPARATIONS' 'ERYTHROPOIESIS-STIMULATING AGENTS'
#  'VACCINE/TOXOID PREPARATIONS,COMBINATIONS'
#  'GENETIC D/O TX - SMN PROTEIN DEFICIENCY TREATMENT'
#  'VITAMIN E PREPARATIONS' 'MULTIVITAMIN PREPARATIONS'
#  'NEUROTOXIC VIRUS VACCINES' 'COUGH AND/OR COLD PREPARATIONS'
#  'ANTICHOLINERGICS/ANTISPASMODICS' 'ANTIHYPERTENSIVES, ACE INHIBITORS'
#  'ANTINEOPLASTIC - ANTIMETABOLITES' 'ANTIGENIC SKIN TESTS'
#  'NOSE PREPARATIONS, MISCELLANEOUS (OTC)'
#  'NSAIDS,CYCLOOXYGENASE-2(COX-2) SELECTIVE INHIBITOR'
#  'SEROTONIN-2 ANTAGONIST/REUPTAKE INHIBITORS (SARIS)'
#  'IRRITANTS/COUNTER-IRRITANTS' 'MAGNESIUM SALTS REPLACEMENT'
#  'HYPERURICEMIA TX - XANTHINE OXIDASE INHIBITORS'
#  'HYPERURICEMIA TX - URATE-OXIDASE ENZYME-TYPE'
#  'SELECTIVE SEROTONIN REUPTAKE INHIBITOR (SSRIS)'
#  'BETA-ADRENERGIC AND GLUCOCORTICOID COMBO, INHALED'
#  'ANTICONVULSANT - CANNABINOID TYPE' 'EYE ANTI-INFECTIVES (RX ONLY)'
#  'ANTICOAGULANTS,COUMARIN TYPE' 'CYCLIC LIPOPEPTIDES'
#  'ACID AND ALKALI POISON ANTIDOTES' 'DRUGS TO TREAT MOVEMENT DISORDERS'
#  'OPHTHALMIC PREPARATIONS, MISCELLANEOUS' 'EYE LOCAL ANESTHETICS'
#  'ALCOHOL,SYSTEMIC USE' 'MIOTICS AND OTHER INTRAOCULAR PRESSURE REDUCERS'
#  'HEMOPHILIA TREATMENT AGENTS,NON-FACTOR REPLACEMENT'
#  'VIRAL/TUMORIGENIC VACCINES' 'KERATINOCYTE GROWTH FACTOR (KGF)'
#  'ANTITUSSIVES, NON-OPIOID' 'OXAZOLIDINONE ANTIBIOTICS'
#  'FOLIC ACID PREPARATIONS' 'URICOSURIC AGENTS'
#  'IMMUNOSUPP - MONOCLONAL AB INHIBITING T LYMPH FXN'
#  'TETRACYCLINE ANTIBIOTICS' 'TOPICAL AGENTS,MISCELLANEOUS'
#  'OINTMENT/CREAM BASES' 'ANTIOXIDANT AGENTS' 'IODINE CONTAINING AGENTS'
#  'ANDROGENIC AGENTS' 'ANTIDIARRHEALS' 'BONE RESORPTION INHIBITORS'
#  'BULK CHEMICALS' 'VEHICLES' 'ADRENAL RADIOACTIVE DIAGNOSTICS'
#  'EAR PREPARATIONS,EAR WAX REMOVERS' 'BILIARY DIAGNOSTICS,RADIOPAQUE'
#  'HEPATITIS C TREATMENT AGENTS' 'DIGITALIS GLYCOSIDES'
#  'PULMONARY ANTIHYPERTENSIVES, PROSTACYCLIN-TYPE' 'ZINC REPLACEMENT'
#  'XANTHINES' 'HYPERPARATHYROID TX AGENTS - VITAMIN D ANALOG-TYPE'
#  'ALPHA-ADRENERGIC BLOCKING AGENTS' 'ANALGESICS, NON-OPIOID'
#  'CEREBRAL SPINAL RADIOPAQUE DIAGNOSTICS'
#  'AGENTS TO TREAT HYPOGLYCEMIA (HYPERGLYCEMICS)' 'IMMUNOMODULATORS'
#  'ANTINEOPLASTIC - CAR-T CELL IMMUNOTHERAPY'
#  'PULMONARY ANTI-HTN, ENDOTHELIN RECEPTOR ANTAGONIST'
#  'GRAM NEGATIVE COCCI VACCINES'
#  'LHRH(GNRH)AGNST PIT.SUP-CENTRAL PRECOCIOUS PUBERTY' 'GROWTH HORMONES'
#  'ANTI-CD20 (B LYMPHOCYTE) MONOCLONAL ANTIBODY'
#  'RADIOACTIVE METABOLIC FUNCTION DIAGNOSTICS'
#  'ANTIPSYCHOTICS,DOPAMINE ANTAGONISTS,BUTYROPHENONES'
#  'EAR PREPARATIONS,ANTIBIOTICS'
#  'ANTINEOPLASTIC LHRH(GNRH) AGONIST,PITUITARY SUPPR.'
#  'ENTERIC VIRUS VACCINES' 'ANTICHOLINERGICS, ORALLY INHALED LONG ACTING'
#  'ANTIHEMOPHILIC FACTORS' 'DIRECT FACTOR XA INHIBITORS'
#  'NOSE PREPARATIONS, MISCELLANEOUS (RX)' 'ANTINEOPLASTICS,MISCELLANEOUS'
#  'ORAL LIPID SUPPLEMENTS' 'DIETARY SUPPLEMENT, MISCELLANEOUS'
#  'ANTINEOPLASTIC - BRAF KINASE INHIBITORS'
#  'ANTINEOPLASTIC - MEK1 AND MEK2 KINASE INHIBITORS'
#  'LHRH (GNRH) AGONIST ANALOG PITUITARY SUPPRESSANTS'
#  'ANTINEOPLASTIC SYSTEMIC ENZYME INHIBITORS'
#  'URINARY TRACT ANESTHETIC/ANALGESIC AGNT (AZO-DYE)' 'BETALACTAMS'
#  'OTIC PREPARATIONS,ANTI-INFLAMMATORY-ANTIBIOTICS'
#  'ANTIHYPERTENSIVES, ANGIOTENSIN RECEPTOR ANTAGONIST' 'PANCREATIC ENZYMES'
#  'CYSTIC FIB-TRANSMEMB CONDUCT.REG.(CFTR)POTENTIATOR'
#  'ANTI-INFLAMMATORY TUMOR NECROSIS FACTOR INHIBITOR' 'BILE SALTS'
#  'ADRENERGICS, AROMATIC, NON-CATECHOLAMINE' 'DIABETIC SUPPLIES'
#  'COVID-19 VACCINES' 'MINERAL REPLACEMENT, MISCELLANEOUS'
#  'ADRENERGIC VASOPRESSOR AGENTS' 'EXPECTORANTS'
#  'ANTITUBERCULAR ANTIBIOTICS'
#  'DRUG TX-CHRONIC INFLAM. COLON DX,5-AMINOSALICYLAT'
#  'POLYMYXIN ANTIBIOTICS AND DERIVATIVES' 'MINERALOCORTICOIDS'
#  'ANTINEOPLASTIC IMMUNOMODULATOR AGENTS'
#  'TOPICAL IMMUNOSUPPRESSIVE AGENTS' 'LIPOTROPICS' 'EYE ANTIVIRALS'
#  'ANTIVIRALS, HIV-SPECIFIC, PROTEASE INHIBITORS'
#  'THROMBOPOIETIN RECEPTOR AGONISTS' 'ANTIMALARIAL DRUGS'
#  'DRUGS TO TREAT ERECTILE DYSFUNCTION (ED)'
#  'CXCR4 CHEMOKINE RECEPTOR ANTAGONIST' 'VITAMIN A PREPARATIONS'
#  'CEPHALOSPORINS - 5TH GENERATION'
#  'BENIGN PROSTATIC HYPERTROPHY/MICTURITION AGENTS']

# %%
excl_drugs = ['NEUROMUSCULAR BLOCKING AGENTS', 'BETA-ADRENERGIC AGENTS', 'ALPHA/BETA-ADRENERGIC BLOCKING AGENTS', 'BETA-ADRENERGIC BLOCKING AGENTS']

med_admin_filter = med_admin[med_admin['pharm_classname'].isin(excl_drugs)]
# med_admin_filter['pharm_classname'].unique()
patients_med = set(med_admin_filter['pat_enc_csn_sid'])
ex_patients = patients - patients_med

# %%
ex_patients = np.array(list(ex_patients))
print(len(ex_patients))
np.save('./DONOTPUSH/patients', ex_patients)
# Out:
# 287
